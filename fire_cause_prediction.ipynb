# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from correlation_estimators import calculate_pearson
from sampling import pps, accept_reject
from scipy.stats.distributions import norm, expon

PROPERTY = 'fire_size'

dfo = pd.read_csv('./data/FW_Veg_Rem_Combined.csv')

cont_columns_prefix = ['Prec_pre_', "Temp_pre_", "Wind_pre_", "Hum_pre_"]
columns_suffix = [7, 15, 30]

weather_columns = [ x + str(y) for x in cont_columns_prefix for y in columns_suffix]

def preprocess_missing_weather_data(df):
    df_subsample = df[df['Temp_pre_7'] == -1]
    df_clean = df[df['Temp_pre_7'] != -1]
    mean_weather_data = df_clean.groupby(['state', 'discovery_month'])[weather_columns].mean().reset_index()
    df_subsample.drop(weather_columns, axis=1, inplace=True)
    df_subsample = df_subsample.merge(mean_weather_data)
    df_clean = df_clean.append(df_subsample, ignore_index=True)
    return df_clean

df = preprocess_missing_weather_data(dfo)
df_full = df
df = pps(df, PROPERTY, 0.1)

causes = df.stat_cause_descr.unique()
# Out:
# /home/patrik-sh/Documents/ITMO_Classes/Multivariate/tasks/task3/venv/lib/python3.8/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
#correlation_matrix_min

to_drop = list(set(df.columns) - set(['fire_size', 'Temp_pre_7', 'Hum_pre_7', 'Wind_pre_7', 'Prec_pre_7', 'remoteness', 'latitude', 'longitude', 'Temp_cont', 'Hum_cont', 'Wind_cont', 'Prec_cont', 'stat_cause_descr']))

bayesian_net_columns_cont = ['fire_size', 'Temp_pre_7', 'Hum_pre_7', 'Wind_pre_7', 'Prec_pre_7', 'remoteness', 'latitude', 'longitude', 'Temp_cont', 'Hum_cont', 'Wind_cont', 'Prec_cont']

df_min = df.drop(to_drop, axis=1)

for cause in causes:
    print('-------------------------')
    print(f'Mean for {cause} in cont:')
    for prop in bayesian_net_columns_cont:
        print(f'Mean for {prop} is {df_min[prop].mean()}')
# Out:
# -------------------------
# Mean for Debris Burning in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Equipment Use in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Miscellaneous in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Arson in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Campfire in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Lightning in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Missing/Undefined in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Fireworks in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Powerline in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Children in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Smoking in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Railroad in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
# -------------------------
# Mean for Structure in cont:
# Mean for fire_size is 13872.88569847607
# Mean for Temp_pre_7 is 17.390025270448913
# Mean for Hum_pre_7 is 42.86041923949525
# Mean for Wind_pre_7 is 2.8315883353533104
# Mean for Prec_pre_7 is 3.8206920010556344
# Mean for remoteness is 0.2653289862058421
# Mean for latitude is 40.660446765500964
# Mean for longitude is -108.94368671442628
# Mean for Temp_cont is 12.116689122910019
# Mean for Hum_cont is 29.391243993313847
# Mean for Wind_cont is 1.816400894987492
# Mean for Prec_cont is 10.809278876834718
